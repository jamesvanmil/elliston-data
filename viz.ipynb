# %%
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

# %%
data_dir = r'/Users/vanmiljf/onedrive/projects/elliston-captions-data/'

# %%
intensity_files = glob(data_dir + '*.intensity.60.txt')
intensity_files.sort()

# %%
dfs = []
for file in intensity_files:
    df = pd.read_table(file, header=None)
    plt.figure()
    plt.xlabel(file.split('/')[-1])
    df.boxplot([0])

# %%
pitch_files = glob(data_dir + '*.pitch.60.txt')
pitch_files.sort()

# %%
dfs = []
for file in pitch_files:
    df = pd.read_table(file, header=None)
    plt.figure()
    plt.xlabel(file.split('/')[-1])
    df.boxplot([0])
